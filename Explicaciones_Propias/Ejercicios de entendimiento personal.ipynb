# %%
Dinero = int(input("Ingresa cuanto dinero tienes:"))

if Dinero < 0:
    print("Paga tus deudas bro")
elif Dinero <= 10:
    print("no te alcanza ni pal camión we")
elif Dinero <= 100: 
    print("Te alcanza como para dos kosakos de 600ml")
elif Dinero <= 1000:
    print("Rifate la botella bro")
else:
    print("Eres millonario y nos vas a sacar de la pobreza")
# Out:
# Te alcanza como para dos kosakos de 600ml

# %% [markdown]
# # Ejercicio 1: Mayor o menor de edad
# Enunciado: Crea un programa que pida la edad de una persona e imprima si es mayor de edad (18 años o más) o menor de edad.

# %%
Edad = int(input("Ingresa tu edad:"))

if Edad >= 18:
    print("Eres mayor de edad")
else:
    print("Eres menor de edad")
# Out:
# Eres mayor de edad

# %% [markdown]
# # Ejercicio 2: Calculadora de descuentos con operadores lógicos Enunciado:
# Crea un programa que pida la edad y el tipo de visitante (adulto_mayor, profesor, estudiante, u otro). El precio base del boleto general es de $45. Aplica las siguientes reglas usando operadores lógicos (and, or):  Si es adulto_mayor y tiene 60 años o más, recibe un 12% de descuento ($39.60).  Si es profesor O estudiante (sin importar la edad), recibe un 10% de descuento ($40.50).  En cualquier otro caso, paga el precio base de $45.  Caso de prueba 1:Entradas: Edad = 65, Tipo = adulto_mayorSalida esperada: Total a pagar: $39.60Caso de prueba 2:Entradas: Edad = 20, Tipo = estudianteSalida esperada: Total a pagar: $40.50

# %%
Edad = int(input("Ingresa tu edad:"))
Tipo_de_visitante = str(input("Ingresa el tipo de visitante\n -Adulto Mayor \n -Profesor \n -Estudiante"))
Boleto_General = 45
Descuento_para_Mayores = Boleto_General * 0.12
Descuento_P_E = Boleto_General * 0.10


if Edad >= 60 and Tipo_de_visitante == "Adulto Mayor":
    print("Entrada general con descuento para personas de la tercera edad:", Boleto_General - Descuento_para_Mayores,"$" )
elif Tipo_de_visitante == "Profesor" or "Estudiante":
    print("Entrada con decuento para profesores o estudiantes:", Boleto_General - Descuento_P_E,"$")
# Out:
# Entrada general con descuento para personas de la tercera edad: 39.6 $

# %% [markdown]
# # Ejercicio 3: Acumulador de precios con while, Enunciado: Crea un programa que sume el costo de los boletos ingresados por el usuario uno por uno.
# El programa debe pedir el precio del boleto continuamente hasta que el usuario ingrese el número 0. En ese momento, el ciclo debe terminar (usando break o cambiando la condición) y mostrar el gran total acumulado.  Caso de prueba:Entrada 1: 45Entrada 2: 30Entrada 3: 0Salida esperada: El total acumulado a pagar es: $75

# %%
Suma_Boleto = 0

while True:
    boleto = int(input("Ingresa el costo del boleto:"))

    if boleto == 0:
        print("La suma total del costo de los boletos es:", Suma_Boleto,"$")
        break
    elif boleto > 0:
        Suma_Boleto = Suma_Boleto + boleto
    else:
        print("Coloca números positivos por favor")
# Out:
# La suma total del costo de los boletos es: 135 $

# %% [markdown]
# # Ejercicio 5: Contador de visitantes y sumatoria con forEnunciado: Crea un programa que procese exactamente a 4 visitantes utilizando un ciclo for con la función range().
#  En cada iteración (del 1 al 4), debe pedir la edad del visitante y sumar la tarifa correspondiente a un total acumulado según estas tres reglas:  Si la edad es menor a 3 años, entra gratis ($0).  Si tiene entre 3 y 17 años, su boleto cuesta $30.  Si tiene 18 años o más, su boleto cuesta $45.  Al finalizar las 4 iteraciones, el programa debe mostrar el total cobrado.  Caso de prueba (Entradas continuas):Visitante 1: 2Visitante 2: 15Visitante 3: 30Visitante 4: 20Salida esperada: Total cobrado por los 4 visitantes: $120

# %%
suma_boleto = 0
Boleto_General = 45



for i in range(0, 4):
    edad = int(input("Ingresa tu edad:"))
    if edad < 3:
        Menor = 0

    elif edad <= 17:
        juvenil = 30
        
    elif edad >= 18:
        General = 45

    Suma_Total = suma_boleto + edad

print(Suma_Total)
# Out:
# 12
