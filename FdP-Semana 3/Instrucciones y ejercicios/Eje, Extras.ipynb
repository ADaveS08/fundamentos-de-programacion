# %% [markdown]
# # Ejercicio 1: Algoritmo con decisión para descuento por monto
# **Enunciado:** Escribe en lenguaje natural los pasos del algoritmo (modelo Entrada-
# Proceso-Salida) para que una tienda aplique un 10% de descuento cuando la compra
# sea de $300 o más, y muestre el monto del descuento y el total a pagar.
# **Entrada:** `monto = 500`
# **Proceso:** `descuento = 500 * 0.10`, `total = 500 - 50`
# **Salida:** `Monto: 500. Descuento: 50.0. Total a pagar: 450.0`

# %%
Monto = float(input("Ingresa el monto de total de tu compra"))

if Monto >= 300:
    Descuento = Monto * 0.10
    Monto_final = Monto - Descuento
    print(f"Monto total: {Monto}$ \nDescuento del 10% : -{Descuento}$ \nMonto final a pagar: {Monto_final}$")
else:
    print(f"Monto total: {Monto}$ \nDescuento: No aplica \nMonto fina a pagar: {Monto}$")
# Out:
# Monto total: 9.0$
# Descuento: No aplica
# Monto fina a pagar: 9.0$

# %% [markdown]
# # Ejercicio 2: Pseudocódigo en PSeInt que clasifica un número
# Enunciado: Escribe un pseudocódigo que lea un número entero y determine si es positivo, negativo o cero, usando una estructura Si-Entonces-Sino. Entrada: -5 Salida: El número -5 es negativo

# %%
Num = int(input("Ingresa cualquer número:"))

if Num >= 0:
    print(f"El número {Num} es positivo")
else:
    print(f"El número {Num} es negativo")
# Out:
# El número 8 es positivo

# %% [markdown]
# # Ejercicio 6: Calificación con escala de letras
# Enunciado: Crea un programa que pida una calificación numérica (0 a 10) y la convierta a letra: A si es >= 9, B si es >= 8, C si es >= 7, D si es >= 6, F en otro caso. Entrada: 9 Salida: Tu calificación es: A

# %%
Calificacion = int(input("Ingresa una calificacion, max. 10 min. 0:"))

if Calificacion >= 9:
    print("A")   
if Calificacion >= 8:
    print("B")   
if Calificacion >= 7:
    print("C")  
if Calificacion >= 6:
    print("D")   
else:
    print("F")
# Out:
# F

# %% [markdown]
# # Ejercicio 7: Número par o impar
# Enunciado: Crea un programa que pida un número entero y muestre si es par o impar usando el operador módulo %. Entrada: 14 Proceso: 14 % 2 = 0 Salida: 14 es un número par

# %%
numero = int(input("Dame un número entero"))

if numero % 2 == 0:
    print(f"{numero} Es número par")
else:
    print(f"{numero} Es número impar ")
# Out:
# 7 Es número impar

# %% [markdown]
# # Ejercicio 8: El mayor de tres números
# Enunciado: Crea un programa que pida tres números y determine cuál es el mayor, usando decisiones anidadas o comparaciones con and. Entrada: 12, 7, 9 Salida: El mayor es: 12

# %%
num1 = float(input("Ingresa un número:"))
num2 = float(input("Ingresa otro número:"))
num3 = float(input("Ingresa un último número:"))

if num1 and num2 < num3:
    print(f"El número {num3} es el mayor")
# Out:
# El número 9.0 es el mayor

# %% [markdown]
# # Ejercicio 9: Descuento escalonado
# Enunciado: Crea un programa que aplique un descuento según el monto de compra: sin descuento si es menor a $100, 10% si es de $100 a $499, y 20% si es de $500 o más. Muestra el precio final con dos decimales. Entrada: 800 Proceso: descuento = 800 * 0.20, final = 800 - 160 Salida: Precio final con descuento: $640.00

# %%
descuento1 = 0.1
descuento2 = 0.2

compra = int(input("Ingresa el total de tu compra:"))
if compra < 100:
    print(f"Tu compra no aplica con descuento\n Total a pagar:{compra}$")
elif 100 <= compra < 500:
    descuento = compra * descuento1
    print(f"Total de compra con descuento: ${compra - descuento:.2f}")
else:
    descuento = compra * descuento2
    print(f"Total de compra con descuento: ${compra - descuento:.2f}")
# Out:
# Total de compra con descuento: $270.00

# %% [markdown]
# # Ejercicio 10: Tipo de triángulo por sus lados
# Enunciado: Crea un programa que pida tres lados y determine si el triángulo es equilátero (tres lados iguales), isósceles (dos iguales) o escaleno (todos distintos). Entrada: 5, 5, 5 Salida: El triángulo es equilátero

# %%
Lado1 = float(input("Ingresa el lado A del triangulo"))
Lado2 = float(input("Ingresa el lado B del triangulo"))
Lado3 = float(input("Ingresa el lado C del triangulo"))

if Lado1 == Lado2 and Lado1 == Lado2:
    print("El triángulo es Equilátero")
elif Lado1 == Lado2 or Lado1 == Lado3:
    print("Tu triángulo es Isoceles")
else:
    print("Tu triangulo es Escaleno")
# Out:
# El triángulo es Equilátero

# %% [markdown]
# # Ejercicio 11: Suma con centinela 0
# Enunciado: Crea un programa que sume números positivos ingresados por el usuario y se detenga cuando ingrese 0, mostrando la suma total. Entrada: 4, 6, 10, 0 Proceso: suma = 4 + 6 + 10 Salida: La suma es: 20

# %%
numeros = 0 
total = 0
suma = 0
numeros = int(input("Ingresa un número:"))
while numeros !=0:
    suma+=numeros
    numeros = int(input("Ingresa otro número: ") or "0")
    total = suma
print(f"La suma de tus numeros es igual a: {total}")
# Out:
# La suma de tus numeros es:, 4
