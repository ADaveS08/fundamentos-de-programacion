# %% [markdown]
# Este archi

# %%
nombre = "Dave"
edad = 18
es_estudiante = True
esta_activo = None

print(type(nombre))
print(type(nombre))
print(type(es_estudiante))
print(type(esta_activo))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'bool'>
# <class 'NoneType'>

# %%
nombre = "Dave"
edad = 18
print("hola bro", nombre, "ya vi que tienes", edad, "años de edad")
# Out:
# hola bro Dave ya vi que tienes 18 años de edad

# %% [markdown]
# En este punto inicialice el proyecto en git

# %% [markdown]
# ## algoritmo para calcular velocidad##

# %%
distancia = float(input("ingrese la distancia en Km:"))
tiempo = float(input("Ingrese el tiempo en horas"))

print("El dato distancia es tipo:", type(distancia))
print("El dato timpo es tipo:", type(tiempo) )



velocidad = distancia / tiempo

print("La velocidad promedio es:", velocidad)
# Out:
# El dato distancia es tipo: <class 'float'>
# El dato timpo es tipo: <class 'float'>
# La velocidad promedio es: 1.3333333333333335

# %%
a = 6
b = 4

print(a + b)
print(a == b)
print(a < b)
print(a != b)
# Out:
# 10
# False
# False
# True

# %%
nombre =input("Ingresa tu name:")
edad = int(input("Ingresa tu edad, bro:"))

print(f"Te llamas {nombre} \nTu edad es {edad}")
# Out:
# Te llamas d
# Tu edad es 3

# %% [markdown]
# ### Desafío Extra 1: Convertidor de Temperatura

# %%
#Formula Fahrenheit
C = float(input("Ingresa la temperatura en grados Celsius: "))
F = (C * 9/5) + 32
K = C + 273.15

print(f"Temperatura en Celsius: {C}grados Celsius")
print(f"Temperatura en Fahrenheit: {F}grados Fahrnheit")
print(f"Temperatura en Kelvin: {K}Kelvin")
# Out:
# Temperatura en Celsius: 40.0grados Celsius
# Temperatura en Fahrenheit: 104.0grados Fahrnheit
# Temperatura en Kelvin: 313.15Kelvin

# %% [markdown]
# # ACTIVIDAD EVALUABLE 1 — CALCULADORA DE TIEMPO DIGITAL

# %%
nombre_de_usuario = input("Ingresa tu nombre de usuario:")

redes_sociales = float(input("(En Horas)Ingresa cuanto tiempo le dedicas a redes sociales:"))
WhatsApp = float(input("(En Horas)Ingresa cuanto tiempo le dedicas a instagram:"))
TikTok = float(input("(En Horas)ingresa cuanto tiempo le dedicas al TikTok:"))
Canvas = float(input("(En Horas) Ingresa cuanto timpo le dedicas a esta app:"))
Facebook = float(input("(En Horas) Ingresa cuanto tiempo le dedics al facebook:"))

Tiempo_total = (redes_sociales + WhatsApp + TikTok + Canvas + Facebook)

print(nombre_de_usuario)
print(f"pasas un total de {Tiempo_total} horas")
porcentaje = ( Tiempo_total / 24) * 100
print(f"ocupas el {porcentaje} % del dia ")
# Out:
# de
# pasas un total de 12.0 horas
# ocupas el 50.0 % del dia

# %% [markdown]
# # Extra 1: División de cuenta con propina

# %%
Total_de_cuenta = 250
porcentaje_de_propina = 15
Personas = 4

propina = Total_de_cuenta * (porcentaje_de_propina / 100)

total = Total_de_cuenta + propina

pago_por_persona = Total_de_cuenta / Personas

print(f"La propina es de {propina}$ \n El total con propina es de {total}$ \n el pago por pesona es de {pago_por_persona}$")
# Out:
# La propina es de 37.5$
#  El total con propina es de 287.5$
#  el pago por pesona es de 62.5$

# %% [markdown]
# # Extra 2: Conversor de minutos a días, horas y minutos

# %%
minutos  = 1440
horas = minutos / 60
dias = minutos / 1440

minutos = float(input("Ingresa los minutos: "))

print(f"dias {dias} \n horas {horas} \n minutos restantes {minutos} ")
# Out:
# dias 1.0
#  horas 24.0
#  minutos restantes 60.0

# %% [markdown]
# Extra 3: Calificación final ponderada

# %%
Calificacion_1 = float(input("ingresa la calificación del primer parcial:"))
Calificacion_2 = float(input("ingresa la calificación del segundo parcial:"))
Calificacion_3 = float(input("ingresa la calificación del tercer parcial:"))

Calificacion_1 * 0.30
Calificacion_2 * 0.30
Calificacion_3 * 0.40

Calificacion_final = (Calificacion_1 + Calificacion_2 + Calificacion_3) / 3


print(f"Tu calificacion final es f"{Calificacion_final}:.2f"")
# Out:
#   Cell In[10], line 12
#     print(f"Tu calificacion final es f"{Calificacion_final}:.2f"")
#                                                              ^
# SyntaxError: invalid decimal literal
