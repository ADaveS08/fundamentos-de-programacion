# %% [markdown]
# # Actividad Principal 4:
# Crear una aplicación interactiva en Python que demuestre el uso integral de tuplas, diccionarios, manipulación de cadenas de texto (strings) y manejo robusto de excepciones, estructurada a través de un menú principal modular controlado por un ciclo. El usuario debe poder seleccionar por número qué sección desea ejecutar (Tuplas, Diccionarios, Excepciones, Strings o Finalizar) y el programa debe delegar cada tarea a funciones modulares.
#
# Este reto integra la creación y manipulación de tuplas (Tema 13), los diccionarios con claves y valores (Tema 14), los bloques try-except con excepciones específicas (Tema 15) y los métodos de strings con conteo de palabras (Tema 16), además de consolidar las funciones con y sin retorno vistas en semanas anteriores.

# %%
# OPCION 1 - tuoplas


def trabajar_tuplas():

    # Tupla inicial
    calificaciones = (7.5, 9.0, 8.0, 6.5, 10.0)

    # Imprimir el tercer Numero
    print("\nTercer Calificación:", calificaciones[2])

    # Capturar dos calificaciones adicionales
    Numero1 = float(input("Ingresa la sexta calificación: "))
    Numero2 = float(input("Ingresa la septima calificación: "))

    
    nueva_tupla = calificaciones + (Numero1, Numero2)

    print("Nueva tupla:", nueva_tupla)

   
    lista_calificaciones = list(nueva_tupla)

    # Ordenar de mayor a menor
    lista_calificaciones.sort(reverse=True)

    print("Lista ordenada (mayor a menor):", lista_calificaciones)

    # Función para sumar los números
    def sumar_calificaciones(tupla):
        return sum(tupla)

    
    suma = sumar_calificaciones(nueva_tupla)

    print("Suma total:", suma)


# ==========================================================
# OPCION 2 - DICCIONARIOS


def trabajar_diccionarios():

    # Diccionario de contactos inicial
    contactos = {
        "Ana": "555-0101",
        "Luis": "555-0102",
        "Mía": "555-0103"
    }

    # Capturar nuevo contacto
    Nombre = input("\nNombre del nuevo contacto: ")
    Numero = input("Teléfono del nuevo contacto: ")

    # Agregar el nuevo contacto
    contactos[Nombre] = Numero

    # Mostrar solamente los nombres
    print("\nContactos registrados:")

    for nombre in contactos.keys():
        print(nombre, end=", ")

    print()

    # Función para buscar teléfono
    def obtener_telefono(diccionario_contactos, nombre):
        return diccionario_contactos.get(nombre, "Contacto no encontrado")

    # Buscar el nuevo contacto
    Nombre_buscar = input("Nombre a buscar: ")

    telefono_encontrado = obtener_telefono(contactos, Nombre_buscar)

    print(f"El teléfono de {Nombre_buscar} es: {telefono_encontrado}")


###############################################################3
# OPCION 3 - EXCEPCIONES


def trabajar_excepciones():

    try:

        # Solicitar dos números enteros
        Num1 = int(input("\nPrimer número entero: "))
        Num2 = int(input("Segundo número entero: "))

        Resultado = Num1 / Num2

        print(f"{Num1} dividido entre {Num2} es: {Resultado}")

    except ValueError:

        print("Error: Debes ingresar números enteros. No se permite texto ni valores vacíos.")

    except ZeroDivisionError:

        print("Error: No es posible dividir entre cero. Ingresa un divisor distinto de 0.")


#######################################################################################
# OPCION 4 - STRINGS


def trabajar_strings():

    # Mensaje inicial
    mensaje = "Python es un lenguaje poderoso"

    # Longitud del mensaje
    print("\nLongitud del mensaje:", len(mensaje))

    # Convertir a mayúsculas
    print("En mayúsculas:", mensaje.upper())

    # Reemplazar una palabra
    texto_reemplazado = mensaje.replace("Python", "programación")

    print("Texto reemplazado:", texto_reemplazado)

    # Función para contar palabras
    def contar_palabras(texto):
        return len(texto.split())

    # Mostrar cantidad de palabras
    total_palabras = contar_palabras(mensaje)

    print("Palabras totales:", total_palabras)


# ==========================================================
# MENU PRINCIPAL
# ==========================================================

while True:

    print("\n===================================")
    print("       MENU PRINCIPAL")
    print("-----------------------------------")
    print("(1) Trabajar con tuplas")
    print("(2) Trabajar con diccionarios")
    print("(3) Manejo de excepciones")
    print("(4) Analizar strings")
    print("(5) Finalizar el programa")
    print("-----------------------------------")

    try:
        Opcion = int(input("Ingresa la opción numérica: "))

        if Opcion == 1:

            trabajar_tuplas()

        elif Opcion == 2:

            trabajar_diccionarios()

        elif Opcion == 3:

            trabajar_excepciones()

        elif Opcion == 4:

            trabajar_strings()

        elif Opcion == 5:

            print("\nPrograma finalizado.")
            break

        else:

            print("\nError: Selecciona una opción del 1 al 5.")

    except ValueError:

        print("\nError: Debes ingresar un número del 1 al 5.")
# Out:
# ...
#        MENU PRINCIPAL
# -----------------------------------
# (1) Trabajar con tuplas
# (2) Trabajar con diccionarios
# (3) Manejo de excepciones
# (4) Analizar strings
# (5) Finalizar el programa
# -----------------------------------
#
# Tercer Calificación: 8.0
# Nueva tupla: (7.5, 9.0, 8.0, 6.5, 10.0, 8.5, 9.5)
# Lista ordenada (mayor a menor): [10.0, 9.5, 9.0, 8.5, 8.0, 7.5, 6.5]
# Suma total: 59.0
#
# ...
#        MENU PRINCIPAL
# -----------------------------------
# (1) Trabajar con tuplas
# (2) Trabajar con diccionarios
# (3) Manejo de excepciones
# (4) Analizar strings
# (5) Finalizar el programa
# -----------------------------------
#
# Programa finalizado.
# El kernel se bloqueó al ejecutar código en la celda actual o en una celda anterior.
#
# Revise el código de las celdas para identificar una posible causa del error.
#
# Haga clic <a href='https://aka.ms/vscodeJupyterKernelCrash'>aquí</a> para obtener más información.
#
# ...
