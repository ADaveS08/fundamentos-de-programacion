# %%
archivo = open("archivo.txt", mode="w")
archivo.write("Esto es una segunda linea")
archivo.close()
print("Se han escrito en el archivo saludo.txt")
# Out:
# Se han escrito en el archivo saludo.txt
